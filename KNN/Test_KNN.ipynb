# %%
import os,sys
from numpy import *
import kNN

#print("sys.argv[0] %s"%(sys.argv[0]))
#print("sys.argv %s"%(sys.argv))
#print("os.getcw %s"%(os.getcwd()))
#print("sys.path %s"%(sys.path))

#returnMat,classLabelVector = kNN.file2matrix("datingTestSet2.txt")
#normMat, ranges, minVals = kNN.autoNorm(returnMat)
#print(returnMat.min(0))
#print(returnMat.max(0))
# numpy ndarray test multi dimensions array ,or multi dimensions matrix
# print(returnMat[:5,:2])
# print("--------------------------------------------")
# print(type(minVals))
# print("--------------------------------------------")
# print(len(minVals))
# print("--------------------------------------------")
# print(minVals)
# print("--------------------------------------------")
# print(minVals.shape)
# print("--------------------------------------------")
# print(tile(minVals, (returnMat.shape[0],2,2))[:2])
# print("--------------------------------------------")
# print(len(tile(minVals, (returnMat.shape[0],2,2))[:2]))
# print("--------------------------------------------")
# print(shape(tile(minVals, (returnMat.shape[0],2,2))))
# print("--------------------------------------------")
# print(shape(tile((1,2,3,4,5,6), (500,200,100,1))))
# print("--------------------------------------------")
# print((tile((1,2,3,4,5,6), (500,200,100,1)))[:2])
# print("--------------------------------------------")
# print(shape((tile((1,2,3,4,5,6), (500,200,100,2)))[:2]))

#sum function test
#print(tile(returnMat[0],(5,2,1)))
#print(shape(tile(returnMat[0],(5,2,1))))
#returnMat[:3].sum(axis=0)
#print(tile(returnMat[0],(5,2,1)).sum(axis=0))
#print(shape(tile(returnMat[0],(5,2,1)).sum(axis=0)))

kNN.datingClassTest()
# Out:
# the classifier came back with: 3, the real answer is: 3
# the classifier came back with: 2, the real answer is: 2
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 3, the real answer is: 3
# the classifier came back with: 3, the real answer is: 3
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 3, the real answer is: 3
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 2, the real answer is: 2
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# the classifier came back with: 1, the real answer is: 1
# ...
